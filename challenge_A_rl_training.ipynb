# %% [markdown]
# # **RL4AA'25 Challenge Part 2:** Option RL
#
# In this notebook you can solve the RL challenge by training your own RL agent. If you are a beginner in RL, we recommend you stick the with provided code using the PPO implementation from _Stable Baselines3_, and try to tune the hyperparameters of both the environment and the PPO algorithm through the `config` dictionary. If you are more experienced, feel free to change the algorithm or move to a completely different RL library altogether, provided you believe that it will help you solve the challenge.
#
# ## IMPORTANT: PLEASE READ BEFORE RUNNING THE NOTEBOOK
#
# Training a good RL agent can take a lot of time. The task in this challenge was designed such that 500,000 steps should be enough to solve it well. (Though you can train longer if you think you can do better. 😉) On a Mac with an Apple-made SoC, such a training should be doable in about 10 minutes. It may take longer on other machines, expect at least 30 minutes on a recent Windows or Linux laptop.
#
# **More importantly** this training can use a considerable amount of RAM. In the worst case, this can also cause other applications to crash when you start training. So please make sure you have nothing unsaved open on your computer before you start training, and that you follow the instructions on setting `n_envs` correctly. When in doubt use a lower number.
#
# The following code also uses (_Weight & Biases_)[https://wandb.ai] to log the training. We recommend you create a free account there and check out the results to better understand what is happening during training. If you don't want to use _Weight & Biases_, run `wandb disabled` in a terminal in the root of this repository. You can then still use Tensorboard to visualise the training progress by running `tensorboard --logdir log/` in a terminal in the root of this repository.

# %%
from functools import partial
from pathlib import Path

import numpy as np
import torch.nn as nn
from rl_zoo3 import linear_schedule
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from wandb.integration.sb3 import WandbCallback

import wandb
from src.eval import Study
from src.eval.eval_rl_v3_sim import evaluate_policy
from src.train.ea_ppo import make_env
from src.utils import load_config, save_config

# %% [markdown]
# ## Configure the RL training with the PPO algorithm from _Stable Baselines3_
#
# Below you find the `config` dictionary that contains all the hyperparameters for the PPO algorithm and the environment. You can change the values to optimise the training of your agent.
#
# You may also modify the `_get_reward` method of the environment to change the reward function. It can be found in [`src/environments/ea.py` line 338](src/environments/ea.py:338).

# %%
config = {
    # ===== Environment parameters =====
    # You may change any of these. However, be aware that in the evaluation, some of
    # these parameters are set to different values, regardless of what you set in
    # the training. It may or may not make sense to change them here. You will just have
    # to find out what happens yourself.
    # ---------------------
    # Choose weather actions set magnet settings directly (`"direct"`) or change magnet
    # settings (`"delta"`)
    "action_mode": "delta",
    # Maximum allowed quadrupole setting. The real quadrupoles can be set from -72 to
    # 72. These limits are imposed by the power supplies, but are unreasonably high to
    # the task at hand. It might therefore make sense to choose a lower value.
    "max_quad_setting": 30.0,
    # Limit of by how much quadrupole settings may be changed when `action_mode` is set
    # to `"delta"`. This parameter is ignored when `action_mode` is set to `"direct"`.
    "max_quad_delta": 30.0,
    # Limit of by how much steerer settings may be changed when `action_mode` is set to
    # `"delta"`. This parameter is ignored when `action_mode` is set to `"direct"`.
    "max_steerer_delta": 6.1782e-3,
    # Magnet initialisation on `reset`. Set to `None` for magnets to stay at their
    # current settings, `"random"` to be set to random settings or an array of five
    # values to set them to a constant value.
    "magnet_init_mode": np.array([10.0, -10.0, 0.0, 10.0, 0.0]),
    # Setting for incoming beam parameters on reset. Can be `"random"` to generate
    # random parameters or an array of 11 values to set them to a constant value.
    "incoming_mode": "random",
    # Setting for misalignment of magnets and the diagnostic screen on reset. Can be
    # `"random"` to generate random misalignments or an array of 8 values to set them to
    # a constant value.
    # NOTE: This is fixed to `"random"` in the evaluation.
    "misalignment_mode": "random",
    # Maximum misalignment of magnets and the diagnostic screen in meters when
    # `misalignment_mode` is set to `"random"`. This parameter is ignored when
    # `misalignment_mode` is set to a constant value.
    # NOTE: This is fixed to `5e-4` in the evaluation.
    "max_misalignment": 5e-4,
    # If `True`, the screen is assumed to be finite and false false beam parameters are
    # returned when the beam is not on the screen. The false beam parameters are
    # estimates of what would be measured on the real screen as a result of the camera
    # vignetting when no beam is visible.
    # NOTE: That these false beam parameters would always be returned and therefore also
    # be used for the reward computation.
    # NOTE: This is fixed to `True` in the evaluation.`
    "simulate_finite_screen": False,
    # Setting of target beam on `reset`. Set to "random" to generate a random target
    # beam or to an array of four values to set it to a constant value.
    # NOTE: This is fixed to `"np.zeros(4)"` in the evaluation. You can try training on
    # random, but this is significantly harder and out of scope for this challenge.
    "target_beam_mode": np.zeros(4),
    # If `True`, magnet settings are clipped to their allowed ranges after each step.
    "clip_magnets": True,
    # ===== Wrapper parameters =====
    # Number of observations into the past that are passed to the policy. A value of 1
    # means that only the current observation is passed.
    "frame_stack": 1,
    # Whether to scale the observations from their physical ranges to a range of [-1, 1]
    # before passing them to the policy.
    "normalize_observation": True,
    # Whether to expect the policy to output actions in the range of [-1, 1] (`True`) or
    # in the physical range of the actions (`False`).
    "rescale_action": True,
    # NOTE: Please do not change the `target_threshold` parameter.
    "target_threshold": None,
    # Number of steps per episode allowed during training before the environment is
    # reset.
    # NOTE: In the evaluation policies will be run for an arbitrary number of steps.
    "max_episode_steps": 50,
    # ===== RL algorithm parameters =====
    # Please refer to the Stable Baselines3 documentation for the meaning of these
    # parameters:
    #   https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#parameters
    # NOTE: Good settings of `n_steps` and `n_envs` depend a lot on your hardware, and
    # they depend on each other. We recommend using one of the following options based
    # on your hardware:
    #   - 32 GB RAM or more: `n_envs=40`, `n_steps=64`
    #   - 16 GB RAM: `n_envs=20`, `n_steps=128`
    #   - 8 GB RAM: `n_envs=10`, `n_steps=256`
    # USING TOO LARGE VALUES MAY CAUSE OTHER APPLICATIONS TO CRASH WITHOUT WARNING!!!
    "batch_size": 64,
    "learning_rate": 0.0003,
    "lr_schedule": "constant",  # Can be "constant" or "linear"
    "gamma": 0.99,
    "n_envs": 40,
    "n_steps": 64,
    "ent_coef": 0.0,
    "n_epochs": 10,
    "gae_lambda": 0.95,
    "clip_range": 0.2,
    "clip_range_vf": None,  # None,
    "vf_coef": 0.5,
    "max_grad_norm": 0.5,
    "use_sde": False,
    "sde_sample_freq": -1,
    "target_kl": None,
    "total_timesteps": 500_000,
    # ===== Policy parameters =====
    # Size of the policy network. Can be "small" or "medium". Alternatively define
    # custom layer sizes below.
    "net_arch": "small",
    # Activation function of the policy network. Can be "Tanh", "ReLU" or "GELU".
    "activation_fn": "Tanh",
    # Whether or not to use orthogonal initialisation of the policy network weights.
    "ortho_init": True,  # True, False
    # Initial value of the log standard deviation of the policy network output.
    "log_std_init": 0.0,
    # ===== SB3 configuration =====
    # PyTorch device used for training. You should probably leave this at "auto".
    "sb3_device": "auto",
    # Setting for how parallel environments for training rollouts handled. Set to
    # "dummy" for parallel environments to be called in a for loop on a single process,
    # or to "subproc" for parallel environments running in separate processes.
    "vec_env": "subproc",
}

# %% [markdown]
# ## Train your RL agent
#
# Below is the code for training the RL agent with the PPO algorithm as implemented in _Stable Baselines3_. You probably shouldn't change this cell unless you know what you are doing. If you want to use a different algorithm, you will need to change the code below.

# %%
# Setup wandb
wandb.init(
    project="rl4aa25-challenge",
    sync_tensorboard=True,
    monitor_gym=True,
    config=config,
    dir=".wandb",
)
config = dict(wandb.config)
config["run_name"] = wandb.run.name

# Setup vecorised environments for training and evaluation
assert config["vec_env"] in ["dummy", "subproc"]
vec_env = (
    DummyVecEnv([partial(make_env, config) for _ in range(config["n_envs"])])
    if config["vec_env"] == "dummy"
    else SubprocVecEnv([partial(make_env, config) for _ in range(config["n_envs"])])
)
eval_vec_env = DummyVecEnv(
    [partial(make_env, config, plot_episode=True, log_task_statistics=True)]
)

# Setup learning rate schedule if needed
if config["lr_schedule"] == "linear":
    config["learning_rate"] = linear_schedule(config["learning_rate"])

# Setup RL training algorithm
model = PPO(
    "MlpPolicy",
    vec_env,
    learning_rate=config["learning_rate"],
    n_steps=config["n_steps"],
    batch_size=config["batch_size"],
    n_epochs=config["n_epochs"],
    gamma=config["gamma"],
    gae_lambda=config["gae_lambda"],
    clip_range=config["clip_range"],
    clip_range_vf=config["clip_range_vf"],
    ent_coef=config["ent_coef"],
    vf_coef=config["vf_coef"],
    max_grad_norm=config["max_grad_norm"],
    use_sde=config["use_sde"],
    sde_sample_freq=config["sde_sample_freq"],
    target_kl=config["target_kl"],
    policy_kwargs={
        "activation_fn": getattr(nn, config["activation_fn"]),
        "net_arch": {  # From rl_zoo3
            "small": {"pi": [64, 64], "vf": [64, 64]},
            "medium": {"pi": [256, 256], "vf": [256, 256]},
        }[config["net_arch"]],
        "ortho_init": config["ortho_init"],
        "log_std_init": config["log_std_init"],
    },
    device=config["sb3_device"],
    tensorboard_log=f"log/{config['run_name']}",
    verbose=1,
)

# Setup callbacks for evaluation and logging
eval_callback = EvalCallback(eval_vec_env, eval_freq=1_000, n_eval_episodes=5)
wandb_callback = WandbCallback()

# Train the model
model.learn(
    total_timesteps=config["total_timesteps"],
    callback=[eval_callback, wandb_callback],
)

# Save the model and associated configuration
model.save(f"models/ea/ppo/{wandb.run.name}/model")
save_config(config, f"models/ea/ppo/{wandb.run.name}/config")

# Cleanup environments
vec_env.close()
eval_vec_env.close()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: jank324 (msk-ipc) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path .wandb/wandb/ wasn't writable, using system temp directory.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/var/folders/z8/vzg_1dr50gg1zchydp1styc00000gn/T/wandb/run-20250321_190829-k4r7dydg</code>
# Syncing run <strong><a href='https://wandb.ai/msk-ipc/rl4aa-tutorial-2025/runs/k4r7dydg' target="_blank">rare-wood-2</a></strong> to <a href='https://wandb.ai/msk-ipc/rl4aa-tutorial-2025' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/msk-ipc/rl4aa-tutorial-2025' target="_blank">https://wandb.ai/msk-ipc/rl4aa-tutorial-2025</a>
#  View run at <a href='https://wandb.ai/msk-ipc/rl4aa-tutorial-2025/runs/k4r7dydg' target="_blank">https://wandb.ai/msk-ipc/rl4aa-tutorial-2025/runs/k4r7dydg</a>
# Using cpu device
# Logging to log/rare-wood-2/PPO_1
# /opt/homebrew/Caskroom/miniforge/base/envs/rl4aa25-tutorial/lib/python3.12/site-packages/stable_baselines3/common/callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x15f3dc320> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x15f394e90>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    fps             | 265      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2560     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 447         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.007740155 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.09       |
# |    explained_variance   | 0.00136     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.29        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0093     |
# |    std                  | 0.996       |
# |    value_loss           | 55.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.009505076 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.08       |
# |    explained_variance   | -0.0123     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.45        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00715    |
# |    std                  | 0.997       |
# |    value_loss           | 31          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009150554 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.08       |
# |    explained_variance   | 0.000728    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.03        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00499    |
# |    std                  | 0.997       |
# |    value_loss           | 30.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 769          |
# |    iterations           | 5            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0086405305 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.08        |
# |    explained_variance   | -0.000709    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.35         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00517     |
# |    std                  | 0.991        |
# |    value_loss           | 29.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 6           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.009589346 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.05       |
# |    explained_variance   | -0.0082     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.54        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00587    |
# |    std                  | 0.989       |
# |    value_loss           | 19.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 7           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.009022797 |
# |    clip_fraction        | 0.0577      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.04       |
# |    explained_variance   | 0.000999    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.49        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00532    |
# |    std                  | 0.99        |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 934         |
# |    iterations           | 8           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007348555 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.04       |
# |    explained_variance   | -0.0681     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.46        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00625    |
# |    std                  | 0.986       |
# |    value_loss           | 13.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.010886823 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.02       |
# |    explained_variance   | 0.00126     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.61        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0076     |
# |    std                  | 0.984       |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1013        |
# |    iterations           | 10          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.007743863 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7          |
# |    explained_variance   | 0.0107      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00652    |
# |    std                  | 0.977       |
# |    value_loss           | 6.28        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 1047       |
# |    iterations           | 11         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 28160      |
# | train/                  |            |
# |    approx_kl            | 0.01073352 |
# |    clip_fraction        | 0.0836     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.98      |
# |    explained_variance   | -0.018     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.31       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00961   |
# |    std                  | 0.978      |
# |    value_loss           | 5.02       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1073        |
# |    iterations           | 12          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008872881 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.99       |
# |    explained_variance   | -0.00024    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00974    |
# |    std                  | 0.98        |
# |    value_loss           | 4.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 1099         |
# |    iterations           | 13           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 33280        |
# | train/                  |              |
# |    approx_kl            | 0.0087273065 |
# |    clip_fraction        | 0.0713       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7           |
# |    explained_variance   | 0.000576     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.947        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00987     |
# |    std                  | 0.984        |
# |    value_loss           | 3.33         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1122        |
# |    iterations           | 14          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.008084376 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.02       |
# |    explained_variance   | -0.00316    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.764       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00895    |
# |    std                  | 0.989       |
# |    value_loss           | 2.1         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 1137         |
# |    iterations           | 15           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 38400        |
# | train/                  |              |
# |    approx_kl            | 0.0099211205 |
# |    clip_fraction        | 0.0733       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.03        |
# |    explained_variance   | 0.000756     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.625        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.985        |
# |    value_loss           | 2            |
# ------------------------------------------
# Eval num_timesteps=40000, episode_reward=50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | 50          |
# | time/                   |             |
# |    total_timesteps      | 40000       |
# | train/                  |             |
# |    approx_kl            | 0.008271435 |
# |    clip_fraction        | 0.0678      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.02       |
# |    explained_variance   | -0.00523    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.586       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.987       |
# |    value_loss           | 1.86        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    fps             | 776      |
# |    iterations      | 16       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 40960    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 799         |
# |    iterations           | 17          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 43520       |
# | train/                  |             |
# |    approx_kl            | 0.009932427 |
# |    clip_fraction        | 0.0984      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.02       |
# |    explained_variance   | -0.00138    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.3         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.986       |
# |    value_loss           | 1.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 18          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.009988506 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.98       |
# |    explained_variance   | 0.00195     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.186       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.971       |
# |    value_loss           | 0.801       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 19          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 48640       |
# | train/                  |             |
# |    approx_kl            | 0.011173064 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.92       |
# |    explained_variance   | -0.00221    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.297       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.962       |
# |    value_loss           | 0.871       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 20          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009913538 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.88       |
# |    explained_variance   | 0.000376    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.227       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.955       |
# |    value_loss           | 0.616       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 21          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 53760       |
# | train/                  |             |
# |    approx_kl            | 0.011049561 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.86       |
# |    explained_variance   | -0.00962    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.117       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.951       |
# |    value_loss           | 0.372       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 891         |
# |    iterations           | 22          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 56320       |
# | train/                  |             |
# |    approx_kl            | 0.009533837 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.86       |
# |    explained_variance   | -0.00446    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0944      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.958       |
# |    value_loss           | 0.343       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 906         |
# |    iterations           | 23          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 58880       |
# | train/                  |             |
# |    approx_kl            | 0.009767877 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.85       |
# |    explained_variance   | -0.00213    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.95        |
# |    value_loss           | 0.361       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 922         |
# |    iterations           | 24          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009483346 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.82       |
# |    explained_variance   | -0.000557   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0453      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.944       |
# |    value_loss           | 0.208       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 937         |
# |    iterations           | 25          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 64000       |
# | train/                  |             |
# |    approx_kl            | 0.009902602 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.82       |
# |    explained_variance   | 0.000541    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0375      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.95        |
# |    value_loss           | 0.151       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 951         |
# |    iterations           | 26          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 66560       |
# | train/                  |             |
# |    approx_kl            | 0.008277012 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.82       |
# |    explained_variance   | -0.00731    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0545      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.945       |
# |    value_loss           | 0.162       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 27          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 69120       |
# | train/                  |             |
# |    approx_kl            | 0.007581736 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.82       |
# |    explained_variance   | 0.00274     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0339      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.948       |
# |    value_loss           | 0.128       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 28          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009810552 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.83       |
# |    explained_variance   | 0.00357     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00944     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.951       |
# |    value_loss           | 0.0773      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 989         |
# |    iterations           | 29          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 74240       |
# | train/                  |             |
# |    approx_kl            | 0.009335634 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.84       |
# |    explained_variance   | -0.0211     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000575    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.951       |
# |    value_loss           | 0.0681      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1001        |
# |    iterations           | 30          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 76800       |
# | train/                  |             |
# |    approx_kl            | 0.008881353 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.84       |
# |    explained_variance   | -0.0062     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0204      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.95        |
# |    value_loss           | 0.0769      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 1012        |
# |    iterations           | 31          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 79360       |
# | train/                  |             |
# |    approx_kl            | 0.009070912 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.85       |
# |    explained_variance   | -0.00758    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0018     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.955       |
# |    value_loss           | 0.0458      |
# -----------------------------------------
# Eval num_timesteps=80000, episode_reward=50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 50           |
# |    mean_reward          | 50           |
# | time/                   |              |
# |    total_timesteps      | 80000        |
# | train/                  |              |
# |    approx_kl            | 0.0107209515 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.86        |
# |    explained_variance   | -0.00648     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00824      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0189      |
# |    std                  | 0.954        |
# |    value_loss           | 0.0315       |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    fps             | 852      |
# |    iterations      | 32       |
# |    time_elapsed    | 96       |
# |    total_timesteps | 81920    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 33          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 84480       |
# | train/                  |             |
# |    approx_kl            | 0.010423641 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.84       |
# |    explained_variance   | -0.00126    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0088      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.947       |
# |    value_loss           | 0.0332      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 872          |
# |    iterations           | 34           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 87040        |
# | train/                  |              |
# |    approx_kl            | 0.0101960385 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.85        |
# |    explained_variance   | 0.000522     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00138     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0164      |
# |    std                  | 0.956        |
# |    value_loss           | 0.0305       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 883         |
# |    iterations           | 35          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 89600       |
# | train/                  |             |
# |    approx_kl            | 0.009651433 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.86       |
# |    explained_variance   | 0.000993    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00465    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.955       |
# |    value_loss           | 0.0172      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 894         |
# |    iterations           | 36          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011726789 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.86       |
# |    explained_variance   | 0.00129     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0101     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.955       |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 904          |
# |    iterations           | 37           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 94720        |
# | train/                  |              |
# |    approx_kl            | 0.0096390275 |
# |    clip_fraction        | 0.0993       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.87        |
# |    explained_variance   | -0.000837    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0156      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0148      |
# |    std                  | 0.957        |
# |    value_loss           | 0.017        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 38          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.009064304 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.85       |
# |    explained_variance   | -0.00313    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0281     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.95        |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 39          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 99840       |
# | train/                  |             |
# |    approx_kl            | 0.009595927 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.82       |
# |    explained_variance   | -0.00294    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00315    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.944       |
# |    value_loss           | 0.00702     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 932         |
# |    iterations           | 40          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011429377 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.79       |
# |    explained_variance   | -0.00127    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0362     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.94        |
# |    value_loss           | 0.00704     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 41          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 104960      |
# | train/                  |             |
# |    approx_kl            | 0.010123462 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.78       |
# |    explained_variance   | -0.00234    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0201     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.939       |
# |    value_loss           | 0.00713     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 951        |
# |    iterations           | 42         |
# |    time_elapsed         | 112        |
# |    total_timesteps      | 107520     |
# | train/                  |            |
# |    approx_kl            | 0.00946754 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.77      |
# |    explained_variance   | 0.000407   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0294    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0157    |
# |    std                  | 0.936      |
# |    value_loss           | 0.00397    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 43          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 110080      |
# | train/                  |             |
# |    approx_kl            | 0.010485359 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.76       |
# |    explained_variance   | 0.00402     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0262     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.937       |
# |    value_loss           | 0.00313     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 970        |
# |    iterations           | 44         |
# |    time_elapsed         | 116        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.01012728 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.77      |
# |    explained_variance   | 0.00586    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0117    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0156    |
# |    std                  | 0.937      |
# |    value_loss           | 0.00368    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 45          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 115200      |
# | train/                  |             |
# |    approx_kl            | 0.010554105 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.75       |
# |    explained_variance   | -0.00429    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0374     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.933       |
# |    value_loss           | 0.00253     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 985         |
# |    iterations           | 46          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 117760      |
# | train/                  |             |
# |    approx_kl            | 0.010425337 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.74       |
# |    explained_variance   | 0.000637    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.93        |
# |    value_loss           | 0.00159     |
# -----------------------------------------
# Eval num_timesteps=120000, episode_reward=50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | 50          |
# | time/                   |             |
# |    total_timesteps      | 120000      |
# | train/                  |             |
# |    approx_kl            | 0.009198289 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.72       |
# |    explained_variance   | 7.66e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.032      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.928       |
# |    value_loss           | 0.00153     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    fps             | 872      |
# |    iterations      | 47       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 120320   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 880         |
# |    iterations           | 48          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.009845646 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.71       |
# |    explained_variance   | -0.0038     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00978    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.926       |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 49          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 125440      |
# | train/                  |             |
# |    approx_kl            | 0.010693403 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.68       |
# |    explained_variance   | -0.0102     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0318     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.918       |
# |    value_loss           | 0.000961    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 895         |
# |    iterations           | 50          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 128000      |
# | train/                  |             |
# |    approx_kl            | 0.009716174 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.66       |
# |    explained_variance   | -0.0036     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0316     |
# ...
# |    n_updates            | 1790       |
# |    policy_gradient_loss | -0.00698   |
# |    std                  | 0.432      |
# |    value_loss           | 4.28e-09   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 951         |
# |    iterations           | 181         |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 463360      |
# | train/                  |             |
# |    approx_kl            | 0.015524864 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -3.01       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00734    |
# |    std                  | 0.43        |
# |    value_loss           | 2.87e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 952         |
# |    iterations           | 182         |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 465920      |
# | train/                  |             |
# |    approx_kl            | 0.016198188 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | -2.36       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0257     |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00774    |
# |    std                  | 0.425       |
# |    value_loss           | 2.38e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 954         |
# |    iterations           | 183         |
# |    time_elapsed         | 490         |
# |    total_timesteps      | 468480      |
# | train/                  |             |
# |    approx_kl            | 0.020173293 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | -2.4        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.421       |
# |    value_loss           | 6.99e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 956         |
# |    iterations           | 184         |
# |    time_elapsed         | 492         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.019509846 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | -3.74       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.00853    |
# |    std                  | 0.417       |
# |    value_loss           | 2.04e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 185         |
# |    time_elapsed         | 494         |
# |    total_timesteps      | 473600      |
# | train/                  |             |
# |    approx_kl            | 0.017415704 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | -1.18       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.016      |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00856    |
# |    std                  | 0.409       |
# |    value_loss           | 1.29e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 186         |
# |    time_elapsed         | 495         |
# |    total_timesteps      | 476160      |
# | train/                  |             |
# |    approx_kl            | 0.019723322 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | -1.15       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0114      |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.406       |
# |    value_loss           | 1.43e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 187         |
# |    time_elapsed         | 497         |
# |    total_timesteps      | 478720      |
# | train/                  |             |
# |    approx_kl            | 0.020452797 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | -4.96       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000232   |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00697    |
# |    std                  | 0.4         |
# |    value_loss           | 2.27e-09    |
# -----------------------------------------
# Eval num_timesteps=480000, episode_reward=50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 50          |
# |    mean_reward          | 50          |
# | time/                   |             |
# |    total_timesteps      | 480000      |
# | train/                  |             |
# |    approx_kl            | 0.020443795 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | -1.12       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00834    |
# |    std                  | 0.394       |
# |    value_loss           | 1.5e-09     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    fps             | 934      |
# |    iterations      | 188      |
# |    time_elapsed    | 515      |
# |    total_timesteps | 481280   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 936         |
# |    iterations           | 189         |
# |    time_elapsed         | 516         |
# |    total_timesteps      | 483840      |
# | train/                  |             |
# |    approx_kl            | 0.015611658 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | -1.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.39        |
# |    value_loss           | 2.9e-08     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 939         |
# |    iterations           | 190         |
# |    time_elapsed         | 517         |
# |    total_timesteps      | 486400      |
# | train/                  |             |
# |    approx_kl            | 0.019470332 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | -0.972      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0335     |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.384       |
# |    value_loss           | 1.16e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 941         |
# |    iterations           | 191         |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 488960      |
# | train/                  |             |
# |    approx_kl            | 0.017387528 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | -2.5        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0487     |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.0077     |
# |    std                  | 0.381       |
# |    value_loss           | 9.94e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 943         |
# |    iterations           | 192         |
# |    time_elapsed         | 520         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.020600524 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | -1.56       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0149      |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.378       |
# |    value_loss           | 4.02e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 945        |
# |    iterations           | 193        |
# |    time_elapsed         | 522        |
# |    total_timesteps      | 494080     |
# | train/                  |            |
# |    approx_kl            | 0.01631691 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.17      |
# |    explained_variance   | -0.171     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0347    |
# |    n_updates            | 1920       |
# |    policy_gradient_loss | -0.00892   |
# |    std                  | 0.376      |
# |    value_loss           | 2.21e-07   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 947         |
# |    iterations           | 194         |
# |    time_elapsed         | 524         |
# |    total_timesteps      | 496640      |
# | train/                  |             |
# |    approx_kl            | 0.016723443 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | -0.635      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0206     |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00769    |
# |    std                  | 0.373       |
# |    value_loss           | 3.71e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 948         |
# |    iterations           | 195         |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 499200      |
# | train/                  |             |
# |    approx_kl            | 0.017753324 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | -0.373      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0352      |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00927    |
# |    std                  | 0.371       |
# |    value_loss           | 2.48e-09    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 196         |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.017976863 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | -0.175      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0192     |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.00733    |
# |    std                  | 0.369       |
# |    value_loss           | 1.82e-09    |
# -----------------------------------------
# /opt/homebrew/Caskroom/miniforge/base/envs/rl4aa25-tutorial/lib/python3.12/site-packages/stable_baselines3/common/save_util.py:284: UserWarning: Path 'models/ea/ppo/rare-wood-2' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
# /Users/jankaiser/Documents/DESY/rl4aa25-tutorial/src/wrappers/plot_episode.py:128: UserWarning: WARN: Unable to save episode plot for self.episode_id = 60 because the episode was too short.
#   logger.warn(
# /Users/jankaiser/Documents/DESY/rl4aa25-tutorial/src/wrappers/log_task_statistics.py:72: UserWarning: WARN: Unable to save episode plot for self.episode_id = 60 because the episode was too short.
#   logger.warn(

# %% [markdown]
# ## Evaluate your agent
#
# The following code snippet loads your trained policy and evaluates it on a number of randomly generated tuning problems. This is the task you actually need to solve for the challenge.

# %%
model_name = config["run_name"]
model_path = Path("models") / "ea" / "ppo" / model_name
model = PPO.load(model_path / "model")
config = load_config(model_path / "config")

evaluate_policy(model, config, write_data=True, seed=42)

# %% [markdown]
# Now the results are loaded, shown to you and a CSV file is generated at `data/csvs/[model_name].csv`. This file is the one you need to submit to the challenge.

# %%
study = Study.load(f"data/{model_name}", name=model_name)

# %%
study.evaluate_challenge()
# Out:
# Final MAE: 2023 μm
# Steps to convergence: 4.0
# Sum of magnet changes: 4.75

# %% [markdown]
# You may also admire your trained policy in action by running the following code:

# %%
_ = study.episodes[2].plot_summary()

# %% [markdown]
# ## 🏆 Upload your results to Kaggle
#
# For the chance to win the challenge prize. Go to `data/csvs/` and upload the CSV file via \_"Submit Prediction" to the challenge submission page: https://www.kaggle.com/t/ad56a627d147405fa7b5c8629c8b7cf4
